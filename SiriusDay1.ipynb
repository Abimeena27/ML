# %%
import numpy as np

# %%
ar=np.array([[101,"Ajay",20,"Chennai"],
            [102,"Aman",40,"Hyderabad"],
            [103,"Anita",60,"Banglore"]])
ar
# Out:
# array([['101', 'Ajay', '20', 'Chennai'],
#        ['102', 'Aman', '40', 'Hyderabad'],
#        ['103', 'Anita', '60', 'Banglore']], dtype='<U21')

# %%
import pandas as pd

# %% [markdown]
# Creating A dataframe

# %%
df=pd.DataFrame(ar,columns=['ID','Name','Age','City'])
df
# Out:
#     ID   Name Age       City
# 0  101   Ajay  20    Chennai
# 1  102   Aman  40  Hyderabad
# 2  103  Anita  60   Banglore

# %% [markdown]
# Quantity of DF

# %%
df.shape
# Out:
# (3, 4)

# %%
df.size
# Out:
# 12

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Age', 'City'], dtype='object')

# %% [markdown]
# Changing Values

# %%
df['Name'][0]="Danish"

# %%
df
# Out:
#     ID    Name Age       City
# 0  101  Danish  20    Chennai
# 1  102    Aman  40  Hyderabad
# 2  103   Anita  60   Banglore

# %%
df.iloc[0:2,:3]
# Out:
#     ID    Name
# 0  101  Danish
# 1  102    Aman

# %%
df.assign(income=[1000,2000,3000])
# Out:
#     ID    Name Age       City  income
# 0  101  Danish  20    Chennai    1000
# 1  102    Aman  40  Hyderabad    2000
# 2  103   Anita  60   Banglore    3000

# %%
df.set_index("ID")
# Out:
#        Name Age       City
# ID
# 101  Danish  20    Chennai
# 102    Aman  40  Hyderabad
# 103   Anita  60   Banglore

# %%
df=df.assign(bonus=[934,87,89])

# %%
df
# Out:
#     ID    Name Age       City  bonus
# 0  101  Danish  20    Chennai    934
# 1  102    Aman  40  Hyderabad     87
# 2  103   Anita  60   Banglore     89

# %%
del df['bonus']

# %%
df
# Out:
#     ID    Name Age       City
# 0  101  Danish  20    Chennai
# 1  102    Aman  40  Hyderabad
# 2  103   Anita  60   Banglore

# %% [markdown]
# Visualization

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Line graph

# %%
x=np.array([1,2,3,4])
y=np.array([3,5,2,8])

# %%
plt.plot(x,y)
plt.show()

# %%
plt.bar(x,y)
plt.show()

# %%
plt.scatter(x,y)
plt.show()

# %%
plt.hist(x,bins=2)
plt.show()

# %%
#plt.correlation

# %% [markdown]
# PreProcessing -Exploratory Data Analysis

# %%
#

# %% [markdown]
# Normalization

# %%
from sklearn.preprocessing import MinMaxScaler
mm=MinMaxScaler()
x=mm.filt_transform()
x

# %%
#z-score

# %%
#Robust scaler

# %% [markdown]
# Encoding

# %%
#one hot encoding

# %%
#label encoding

# %%
#Ordinal Encoding

# %%
#target encoding

# %%
#Frequency Encoding
