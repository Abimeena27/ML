# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/Bloood pressure data.csv')
df
# Out:
#       Patient_Number  Level_of_Hemoglobin   Age  BMI  Gender  Smoking  \
# 0                  1                11.28  34.0   23    Male        0
# 1                  2                 9.75  54.0   33    Male        0
# 2                  3                10.79  70.0   49    Male        0
# 3                  4                11.00  71.0   50    Male        0
# 4                  5                14.17  52.0   19    Male        0
# ...              ...                  ...   ...  ...     ...      ...
# 1995            1996                10.14  69.0   26    Male        1
# 1996            1997                11.77  24.0   45  Female        1
# 1997            1998                16.91  18.0   42    Male        0
# 1998            1999                11.15  46.0   45    Male        1
# 1999            2000                11.36  41.0   45    Male        0
#
#       Physical_activity  salt_content_in_the_diet  Level_of_Stress  \
# ...

# %% [markdown]
# **Understanding the Dataset**

# %%
df.shape
# Out:
# (2000, 12)

# %%
df.size
# Out:
# 24000

# %%
df.head(3)
# Out:
#    Patient_Number  Level_of_Hemoglobin   Age  BMI Gender  Smoking  \
# 0               1                11.28  34.0   23   Male        0
# 1               2                 9.75  54.0   33   Male        0
# 2               3                10.79  70.0   49   Male        0
#
#    Physical_activity  salt_content_in_the_diet  Level_of_Stress  \
# 0              45961                     48071                2
# 1              26106                     25333                3
# 2               9995                     29465                2
#
#    Chronic_kidney_disease  Adrenal_and_thyroid_disorders  \
# 0                       1                              1
# 1                       0                              0
# 2                       1                              0
#
#    Blood_Pressure_Abnormality
# 0                           1
# 1                           0
# 2                           1

# %%
df.tail(3)
# Out:
#       Patient_Number  Level_of_Hemoglobin   Age  BMI Gender  Smoking  \
# 1997            1998                16.91  18.0   42   Male        0
# 1998            1999                11.15  46.0   45   Male        1
# 1999            2000                11.36  41.0   45   Male        0
#
#       Physical_activity  salt_content_in_the_diet  Level_of_Stress  \
# 1997              14933                     24753                2
# 1998              18157                     15275                3
# 1999              20729                     30463                1
#
#       Chronic_kidney_disease  Adrenal_and_thyroid_disorders  \
# 1997                       1                              1
# 1998                       0                              1
# 1999                       1                              0
#
#       Blood_Pressure_Abnormality
# 1997                           1
# 1998                           0
# 1999                           1

# %%
df.sample(6)
# Out:
#       Patient_Number  Level_of_Hemoglobin   Age  BMI  Gender  Smoking  \
# 1921            1922                11.18  42.0   23  Female        0
# 1370            1371                10.55  18.0   36    Male        1
# 650              651                 9.84  60.0   45    Male        0
# 935              936                17.44  22.0   40  Female        0
# 137              138                14.54  68.0   34  Female        1
# 1852            1853                13.13  47.0   13  Female        0
#
#       Physical_activity  salt_content_in_the_diet  Level_of_Stress  \
# 1921              29865                     49149                1
# 1370              48152                     20259                3
# 650               21631                     11249                3
# 935               38638                     41595                1
# 137               40321                      6220                2
# 1852              19547                     43852                2
#
# ...

# %%
df.columns
# Out:
# Index(['Patient_Number', 'Level_of_Hemoglobin', 'Age', 'BMI', 'Gender',
#        'Smoking', 'Physical_activity', 'salt_content_in_the_diet',
#        'Level_of_Stress', 'Chronic_kidney_disease',
#        'Adrenal_and_thyroid_disorders', 'Blood_Pressure_Abnormality'],
#       dtype='object')

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       Patient_Number  Level_of_Hemoglobin   Age  BMI  Gender  Smoking  \
# 0                  1                11.28  34.0   23    Male        0
# 1                  2                 9.75  54.0   33    Male        0
# 2                  3                10.79  70.0   49    Male        0
# 3                  4                11.00  71.0   50    Male        0
# 4                  5                14.17  52.0   19    Male        0
# ...              ...                  ...   ...  ...     ...      ...
# 1995            1996                10.14  69.0   26    Male        1
# 1996            1997                11.77  24.0   45  Female        1
# 1997            1998                16.91  18.0   42    Male        0
# 1998            1999                11.15  46.0   45    Male        1
# 1999            2000                11.36  41.0   45    Male        0
#
#       Physical_activity  salt_content_in_the_diet  Level_of_Stress  \
# ...

# %% [markdown]
# **Missing Values**

# %%
df.isnull().sum()
# Out:
# Patient_Number                   0
# Level_of_Hemoglobin              0
# Age                              5
# BMI                              0
# Gender                           0
# Smoking                          0
# Physical_activity                0
# salt_content_in_the_diet         0
# Level_of_Stress                  0
# Chronic_kidney_disease           0
# Adrenal_and_thyroid_disorders    0
# Blood_Pressure_Abnormality       0
# dtype: int64

# %%
df['Age'].mean()
# Out:
# 46.54085213032582

# %%
df['Age'].std()
# Out:
# 17.086267347530974

# %%
df['Age'].var()
# Out:
# 291.9405318713031

# %%
df1=df.fillna(value=df['Age'].std())

# %%
df.isnull().sum()
# Out:
# Patient_Number                   0
# Level_of_Hemoglobin              0
# Age                              5
# BMI                              0
# Gender                           0
# Smoking                          0
# Physical_activity                0
# salt_content_in_the_diet         0
# Level_of_Stress                  0
# Chronic_kidney_disease           0
# Adrenal_and_thyroid_disorders    0
# Blood_Pressure_Abnormality       0
# dtype: int64

# %%
df1.isnull().sum()
# Out:
# Patient_Number                   0
# Level_of_Hemoglobin              0
# Age                              0
# BMI                              0
# Gender                           0
# Smoking                          0
# Physical_activity                0
# salt_content_in_the_diet         0
# Level_of_Stress                  0
# Chronic_kidney_disease           0
# Adrenal_and_thyroid_disorders    0
# Blood_Pressure_Abnormality       0
# dtype: int64

# %% [markdown]
# **Visualize**

# %%
y=df['Blood_Pressure_Abnormality']

# %%
x=df[0:12]

# %%
x
# Out:
#     Patient_Number  Level_of_Hemoglobin   Age  BMI  Gender  Smoking  \
# 0                1                11.28  34.0   23    Male        0
# 1                2                 9.75  54.0   33    Male        0
# 2                3                10.79  70.0   49    Male        0
# 3                4                11.00  71.0   50    Male        0
# 4                5                14.17  52.0   19    Male        0
# 5                6                11.64  23.0   48    Male        1
# 6                7                11.69  43.0   41  Female        0
# 7                8                12.70  48.0   20  Female        0
# 8                9                10.88  72.0   44  Female        0
# 9               10                14.56  40.0   44    Male        0
# 10              11                 8.58  70.0   28    Male        0
# 11              12                12.77  35.0   17  Female        0
#
#     Physical_activity  salt_content_in_the_diet  Level_of_Stress  \
# ...

# %%
x.drop('Blood_Pressure_Abnormality',axis=1)
# Out:
#     Patient_Number  Level_of_Hemoglobin   Age  BMI  Gender  Smoking  \
# 0                1                11.28  34.0   23    Male        0
# 1                2                 9.75  54.0   33    Male        0
# 2                3                10.79  70.0   49    Male        0
# 3                4                11.00  71.0   50    Male        0
# 4                5                14.17  52.0   19    Male        0
# 5                6                11.64  23.0   48    Male        1
# 6                7                11.69  43.0   41  Female        0
# 7                8                12.70  48.0   20  Female        0
# 8                9                10.88  72.0   44  Female        0
# 9               10                14.56  40.0   44    Male        0
# 10              11                 8.58  70.0   28    Male        0
# 11              12                12.77  35.0   17  Female        0
#
#     Physical_activity  salt_content_in_the_diet  Level_of_Stress  \
# ...

# %%
for i in x:
  plt.hist(x[i])
  plt.title(i)
  plt.show()

# %%
x.drop('Gender',axis=1)
# Out:
#     Patient_Number  Level_of_Hemoglobin   Age  BMI  Smoking  \
# 0                1                11.28  34.0   23        0
# 1                2                 9.75  54.0   33        0
# 2                3                10.79  70.0   49        0
# 3                4                11.00  71.0   50        0
# 4                5                14.17  52.0   19        0
# 5                6                11.64  23.0   48        1
# 6                7                11.69  43.0   41        0
# 7                8                12.70  48.0   20        0
# 8                9                10.88  72.0   44        0
# 9               10                14.56  40.0   44        0
# 10              11                 8.58  70.0   28        0
# 11              12                12.77  35.0   17        0
#
#     Physical_activity  salt_content_in_the_diet  Level_of_Stress  \
# 0               45961                     48071                2
# ...

# %%
for i in x:
  if i=='Gender':
    continue
  plt.pie(x[i])
  plt.title(i)
  plt.show()

# %% [markdown]
# **Normalization**

# %%
df2=df1.drop('Gender',axis=1)
from sklearn.preprocessing import RobustScaler
data = RobustScaler()
data.fit(df2)
s_d = data.transform(df2)
s_d
# Out:
# array([[-1.        , -0.0178731 , -0.38709677, ...,  0.        ,
#          1.        ,  1.        ],
#        [-0.9989995 , -0.56478999,  0.25806452, ..., -1.        ,
#          0.        ,  0.        ],
#        [-0.997999  , -0.19302949,  0.77419355, ...,  0.        ,
#          0.        ,  1.        ],
#        ...,
#        [ 0.997999  ,  1.99463807, -0.90322581, ...,  0.        ,
#          1.        ,  1.        ],
#        [ 0.9989995 , -0.06434316,  0.        , ..., -1.        ,
#          1.        ,  0.        ],
#        [ 1.        ,  0.01072386, -0.16129032, ...,  0.        ,
#          0.        ,  1.        ]])

# %%
from sklearn.preprocessing import StandardScaler
data1 = StandardScaler()
data1.fit(df2)
s_d2= data.transform(df2)
s_d2
# Out:
# array([[-1.        , -0.0178731 , -0.38709677, ...,  0.        ,
#          1.        ,  1.        ],
#        [-0.9989995 , -0.56478999,  0.25806452, ..., -1.        ,
#          0.        ,  0.        ],
#        [-0.997999  , -0.19302949,  0.77419355, ...,  0.        ,
#          0.        ,  1.        ],
#        ...,
#        [ 0.997999  ,  1.99463807, -0.90322581, ...,  0.        ,
#          1.        ,  1.        ],
#        [ 0.9989995 , -0.06434316,  0.        , ..., -1.        ,
#          1.        ,  0.        ],
#        [ 1.        ,  0.01072386, -0.16129032, ...,  0.        ,
#          0.        ,  1.        ]])

# %% [markdown]
# **Encoding**

# %%
df1.dtypes
# Out:
# Patient_Number                     int64
# Level_of_Hemoglobin              float64
# Age                              float64
# BMI                                int64
# Gender                            object
# Smoking                            int64
# Physical_activity                  int64
# salt_content_in_the_diet           int64
# Level_of_Stress                    int64
# Chronic_kidney_disease             int64
# Adrenal_and_thyroid_disorders      int64
# Blood_Pressure_Abnormality         int64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
en=LabelEncoder()
en.fit(df1['Gender'])
d=en.transform(df1['Gender'])
d
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
from sklearn.preprocessing  import OrdinalEncoder
Oe=OrdinalEncoder()
d1=Oe.fit_transform(df[['Gender']])
d1
# Out:
# array([[1.],
#        [1.],
#        [1.],
#        ...,
#        [1.],
#        [1.],
#        [1.]])
